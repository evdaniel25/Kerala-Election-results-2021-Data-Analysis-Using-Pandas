# %%
import pandas as pd

# %%
data = pd.read_csv('Assemby Constituency_Kerala_2021.csv')

# %%
data
# Out:
#            AC Name  AC No. Type            District      Winning Candidate  \
# 0            Adoor     115   SC      Pathanamthitta    Chittayam Gopakumar
# 1        Alappuzha     104  GEN           Alappuzha       P.P Chitharanjan
# 2          Alathur      60  GEN            Palakkad           K.D.Prasenan
# 3            Aluva      76  GEN           Ernakulam           Anwar Sadath
# 4      Ambalapuzha     105  GEN           Alappuzha                H.Salam
# ..             ...     ...  ...                 ...                    ...
# 135  Vattiyoorkavu     133  GEN  Thiruvananthapuram       Adv.V.K.Prasanth
# 136        Vengara      41  GEN          Malappuram      P.K Kunjhalikutty
# 137          Vypen      79  GEN           Ernakulam      K.N. Unnikrishnan
# 138  Wadakkanchery      65  GEN            Thrissur  Xavier Chittilappilly
# 139        Wandoor      36   SC          Malappuram          A P Anilkumar
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AC Name            140 non-null    object
#  1   AC No.             140 non-null    int64
#  2   Type               140 non-null    object
#  3   District           140 non-null    object
#  4   Winning Candidate  140 non-null    object
#  5   Party              140 non-null    object
#  6   Total Electors     140 non-null    int64
#  7   Total Votes        140 non-null    int64
#  8   Poll%              140 non-null    float64
#  9   Margin             140 non-null    int64
#  10  Margin %           140 non-null    float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 12.2+ KB

# %%
data.shape
# Out:
# (140, 11)

# %%
data.describe()
# Out:
#          AC No.  Total Electors    Total Votes       Poll%        Margin  \
# count  140.0000      140.000000     140.000000  140.000000    140.000000
# mean    70.5000   187176.157143  148115.042857   79.135714  15934.085714
# std     40.5586    15405.646932   14764.904159    4.551434  11948.138975
# min      1.0000   149439.000000  109386.000000   66.100000     38.000000
# 25%     35.7500   175896.500000  137070.750000   76.000000   6157.750000
# 50%     70.5000   188683.500000  149304.500000   79.250000  14048.000000
# 75%    105.2500   197409.000000  157692.500000   82.425000  23356.000000
# max    140.0000   228468.000000  192958.000000   89.300000  60963.000000
#
#          Margin %
# count  140.000000
# mean    10.808571
# std      8.079537
# min      0.000000
# 25%      4.275000
# 50%      9.450000
# 75%     15.925000
# max     39.500000

# %%
data.head()
# Out:
#        AC Name  AC No. Type        District    Winning Candidate  \
# 0        Adoor     115   SC  Pathanamthitta  Chittayam Gopakumar
# 1    Alappuzha     104  GEN       Alappuzha     P.P Chitharanjan
# 2      Alathur      60  GEN        Palakkad         K.D.Prasenan
# 3        Aluva      76  GEN       Ernakulam         Anwar Sadath
# 4  Ambalapuzha     105  GEN       Alappuzha              H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist Party Of India          204205       154817   75.8
# 1  Communist Party Of India (Marxist)          194187       157357   81.0
# 2  Communist Party Of India (Marxist)          164415       134583   81.9
# 3            Indian National Congress          182360       149489   82.0
# 4  Communist Party Of India (Marxist)          171291       136430   79.6
#
#    Margin  Margin %
# 0    2919       1.9
# 1   11644       7.4
# 2   34118      25.4
# 3   18886      12.6
# 4   11125       8.2

# %%
data.head(10)
# Out:
#        AC Name  AC No. Type            District    Winning Candidate  \
# 0        Adoor     115   SC      Pathanamthitta  Chittayam Gopakumar
# 1    Alappuzha     104  GEN           Alappuzha     P.P Chitharanjan
# 2      Alathur      60  GEN            Palakkad         K.D.Prasenan
# 3        Aluva      76  GEN           Ernakulam         Anwar Sadath
# 4  Ambalapuzha     105  GEN           Alappuzha              H.Salam
# 5     Angamaly      75  GEN           Ernakulam          Roji M John
# 6     Aranmula     113  GEN      Pathanamthitta         Veena George
# 7        Aroor     102  GEN           Alappuzha              Daleema
# 8   Aruvikkara     136  GEN  Thiruvananthapuram     Adv. G. Steephen
# 9     Attingal     128   SC  Thiruvananthapuram           O S Ambika
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist Party Of India          204205       154817   75.8
# ...

# %%
data.tail()
# Out:
#            AC Name  AC No. Type            District      Winning Candidate  \
# 135  Vattiyoorkavu     133  GEN  Thiruvananthapuram       Adv.V.K.Prasanth
# 136        Vengara      41  GEN          Malappuram      P.K Kunjhalikutty
# 137          Vypen      79  GEN           Ernakulam      K.N. Unnikrishnan
# 138  Wadakkanchery      65  GEN            Thrissur  Xavier Chittilappilly
# 139        Wandoor      36   SC          Malappuram          A P Anilkumar
#
#                                   Party  Total Electors  Total Votes  Poll%  \
# 135  Communist Party Of India (Marxist)          195974       136782   69.8
# 136          Indian Union Muslim League          176389       130764   74.1
# 137  Communist Party Of India (Marxist)          165552       130071   78.6
# 138  Communist Party Of India (Marxist)          200294       169019   84.4
# 139            Indian National Congress          214741       169267   78.8
#
#      Margin  Margin %
# 135   21515      15.7
# ...

# %%
data[['AC Name','Winning Candidate']]
# Out:
#            AC Name      Winning Candidate
# 0            Adoor    Chittayam Gopakumar
# 1        Alappuzha       P.P Chitharanjan
# 2          Alathur           K.D.Prasenan
# 3            Aluva           Anwar Sadath
# 4      Ambalapuzha                H.Salam
# ..             ...                    ...
# 135  Vattiyoorkavu       Adv.V.K.Prasanth
# 136        Vengara      P.K Kunjhalikutty
# 137          Vypen      K.N. Unnikrishnan
# 138  Wadakkanchery  Xavier Chittilappilly
# 139        Wandoor          A P Anilkumar
#
# [140 rows x 2 columns]

# %%
data.iloc[1]
# Out:
# AC Name                                       Alappuzha
# AC No.                                              104
# Type                                                GEN
# District                                      Alappuzha
# Winning Candidate                      P.P Chitharanjan
# Party                Communist Party Of India (Marxist)
# Total Electors                                   194187
# Total Votes                                      157357
# Poll%                                              81.0
# Margin                                            11644
# Margin %                                            7.4
# Name: 1, dtype: object

# %%
new_data = data.head(30)
new_data.set_index('AC Name',inplace=True)

# %%
new_data
# Out:
#                  AC No. Type            District         Winning Candidate  \
# AC Name
# Adoor               115   SC      Pathanamthitta       Chittayam Gopakumar
# Alappuzha           104  GEN           Alappuzha          P.P Chitharanjan
# Alathur              60  GEN            Palakkad              K.D.Prasenan
# Aluva                76  GEN           Ernakulam              Anwar Sadath
# Ambalapuzha         105  GEN           Alappuzha                   H.Salam
# Angamaly             75  GEN           Ernakulam               Roji M John
# Aranmula            113  GEN      Pathanamthitta              Veena George
# Aroor               102  GEN           Alappuzha                   Daleema
# Aruvikkara          136  GEN  Thiruvananthapuram          Adv. G. Steephen
# Attingal            128   SC  Thiruvananthapuram                O S Ambika
# Azhikode             10  GEN              Kannur                K V Sumesh
# ...

# %%
new_data.loc['Adoor']
# Out:
# AC No.                                    115
# Type                                       SC
# District                       Pathanamthitta
# Winning Candidate         Chittayam Gopakumar
# Party                Communist Party Of India
# Total Electors                         204205
# Total Votes                            154817
# Poll%                                    75.8
# Margin                                   2919
# Margin %                                  1.9
# Name: Adoor, dtype: object

# %%
new_data.loc['Adoor']['District']
# Out:
# 'Pathanamthitta'

# %%
new_data.index
# Out:
# Index(['Adoor', 'Alappuzha', 'Alathur', 'Aluva', 'Ambalapuzha', 'Angamaly',
#        'Aranmula', 'Aroor', 'Aruvikkara', 'Attingal', 'Azhikode', 'Balusseri',
#        'Beypore', 'Chadayamangalam', 'Chalakkudy', 'Changanassery',
#        'Chathannur', 'Chavara', 'Chelakkara', 'Chengannur', 'Cherthala',
#        'Chirayinkeezhu', 'Chittur', 'Devikulam', 'Dharmadam', 'Elathur',
#        'Eravipuram', 'Eranad', 'Eranakulam', 'Ettumanoor'],
#       dtype='object', name='AC Name')

# %%
new_data.shape
# Out:
# (30, 10)

# %%
data_from_new_data = new_data

# %%
data_from_new_data
# Out:
#                  AC No. Type            District         Winning Candidate  \
# AC Name
# Adoor               115   SC      Pathanamthitta       Chittayam Gopakumar
# Alappuzha           104  GEN           Alappuzha          P.P Chitharanjan
# Alathur              60  GEN            Palakkad              K.D.Prasenan
# Aluva                76  GEN           Ernakulam              Anwar Sadath
# Ambalapuzha         105  GEN           Alappuzha                   H.Salam
# Angamaly             75  GEN           Ernakulam               Roji M John
# Aranmula            113  GEN      Pathanamthitta              Veena George
# Aroor               102  GEN           Alappuzha                   Daleema
# Aruvikkara          136  GEN  Thiruvananthapuram          Adv. G. Steephen
# Attingal            128   SC  Thiruvananthapuram                O S Ambika
# Azhikode             10  GEN              Kannur                K V Sumesh
# ...

# %%
second_data = data

# %%
second_data.set_index(['District'],inplace=True)

# %%
second_data
# Out:
#                           AC Name  AC No. Type      Winning Candidate  \
# District
# Pathanamthitta              Adoor     115   SC    Chittayam Gopakumar
# Alappuzha               Alappuzha     104  GEN       P.P Chitharanjan
# Palakkad                  Alathur      60  GEN           K.D.Prasenan
# Ernakulam                   Aluva      76  GEN           Anwar Sadath
# Alappuzha             Ambalapuzha     105  GEN                H.Salam
# ...                           ...     ...  ...                    ...
# Thiruvananthapuram  Vattiyoorkavu     133  GEN       Adv.V.K.Prasanth
# Malappuram                Vengara      41  GEN      P.K Kunjhalikutty
# Ernakulam                   Vypen      79  GEN      K.N. Unnikrishnan
# Thrissur            Wadakkanchery      65  GEN  Xavier Chittilappilly
# Malappuram                Wandoor      36   SC          A P Anilkumar
#
#                                                  Party  Total Electors  \
# District
# ...

# %% [markdown]
# # Conditional Filtering based on margin greater than 25k and less than 30k

# %%
condition = (second_data['Margin']>25000) & (second_data['Margin']<30000)

# %%
victory_margin_greater_than_25k = second_data.loc[condition,['AC Name','Winning Candidate','Margin','Party']]

# %%
victory_margin_greater_than_25k.max()
# Out:
# AC Name                               Vaikom
# Winning Candidate             Santhakumari K
# Margin                                 29876
# Party                Kerala Congress (Jacob)
# dtype: object

# %% [markdown]
# # Grouping the data based on Party

# %%
party_data = second_data.groupby('Party')

# %%
party_data.last()
# Out:
#                                                  AC Name  AC No. Type  \
# Party
# Communist Party Of India                          Vaikom      95   SC
# Communist Party Of India (Marxist)         Wadakkanchery      65  GEN
# Congress (Secular)                                Kannur      11  GEN
# Independent                                     Thavanur      47  GEN
# Indian National Congress                         Wandoor      36   SC
# Indian National League                   Kozhikode South      28  GEN
# Indian Union Muslim League                       Vengara      41  GEN
# Janadhipathiya Kerala Congress        Thiruvananthapuram     134  GEN
# Janata Dal (Secular)                          Thiruvalla     111  GEN
# Kerala Congress                               Thodupuzha      90  GEN
# Kerala Congress (B)                         Pathanapuram     120  GEN
# Kerala Congress (Jacob)                          Piravom      85  GEN
# ...

# %% [markdown]
# # Find the candidates of INC who won the election

# %%
party_data.get_group('Indian National Congress')
# Out:
#                            AC Name  AC No. Type            Winning Candidate  \
# District
# Ernakulam                    Aluva      76  GEN                 Anwar Sadath
# Ernakulam                 Angamaly      75  GEN                  Roji M John
# Thrissur                Chalakkudy      72  GEN          Saneeshkumar Joseph
# Ernakulam               Eranakulam      82  GEN                  T. J. Vinod
# Alappuzha                  Haripad     107  GEN           Ramesh Chennithala
# Kannur                     Irikkur       9  GEN           Adv. Sajeev Joseph
# Wayanad                   Kalpetta      19  GEN                Adv.T Siddiqu
# Kollam              Karunagappally     116  GEN                  C. R Mahesh
# Kottayam                  Kottayam      97  GEN  Thiruvanchoor Radhakrishnan
# Thiruvananthapuram         Kovalam     139  GEN              Adv. M. Vincent
# Kollam                     Kundara     123  GEN               P.C.Vishnunadh
# ...

# %% [markdown]
# # Find the Candidates of INC who won in Ernakulam District

# %%
party_data_and_district = second_data.groupby(['Party','District'])

# %%
party_data_and_district.get_group(('Indian National Congress','Ernakulam'),[])
# Out:
#                  AC Name  AC No. Type         Winning Candidate  \
# District
# Ernakulam          Aluva      76  GEN              Anwar Sadath
# Ernakulam       Angamaly      75  GEN               Roji M John
# Ernakulam     Eranakulam      82  GEN               T. J. Vinod
# Ernakulam   Muvattupuzha      86  GEN    Dr. Mathew Kuzhalnadan
# Ernakulam        Paravur      78  GEN            V.D. Satheesan
# Ernakulam    Perumbavoor      74  GEN  Adv Eldose P Kunnapillil
# Ernakulam    Thrikkakara      83  GEN            Adv.P.T.Thomas
# Ernakulam  Thripunithura      81  GEN                   K. Babu
#
#                               Party  Total Electors  Total Votes  Poll%  \
# District
# Ernakulam  Indian National Congress          182360       149489   82.0
# Ernakulam  Indian National Congress          166980       137328   82.2
# Ernakulam  Indian National Congress          152489       109386   71.7
# Ernakulam  Indian National Congress          179830       143927   80.0
# ...

# %% [markdown]
# # Find the Parties who actually won atleast 1 seat

# %%
data.Party.unique()
# Out:
# array(['Communist Party Of India', 'Communist Party Of India (Marxist)',
#        'Indian National Congress', 'Kerala Congress(M)', 'Independent',
#        'Janata Dal (Secular)', 'Nationalist Congress Party',
#        'Indian Union Muslim League', 'Kerala Congress',
#        'Congress (Secular)', 'Indian National League',
#        'Loktantrik Janta Dal', 'Kerala Congress (B)',
#        'Kerala Congress (Jacob)', 'National Secular Conference',
#        'Janadhipathiya Kerala Congress',
#        'Revolutionary Marxist Party Of India'], dtype=object)

# %% [markdown]
# # Find the Details of winning related to the row of Pinarayi Vijayan

# %%
person = ['Pinarayi Vijayan']
data.loc[data['Winning Candidate'].isin(person)]
# Out:
#       AC Name  AC No. Type District Winning Candidate  \
# 24  Dharmadam      12  GEN   Kannur  Pinarayi Vijayan
#
#                                  Party  Total Electors  Total Votes  Poll%  \
# 24  Communist Party Of India (Marxist)          184844       159847   86.5
#
#     Margin  Margin %
# 24   50123      31.4

# %% [markdown]
# # How to replace the space in between Names of Parties with underscore

# %%
second_data['Party'] = second_data['Party'].str.replace(' ','_')

# %%
second_data
# Out:
#                           AC Name  AC No. Type      Winning Candidate  \
# District
# Pathanamthitta              Adoor     115   SC    Chittayam Gopakumar
# Alappuzha               Alappuzha     104  GEN       P.P Chitharanjan
# Palakkad                  Alathur      60  GEN           K.D.Prasenan
# Ernakulam                   Aluva      76  GEN           Anwar Sadath
# Alappuzha             Ambalapuzha     105  GEN                H.Salam
# ...                           ...     ...  ...                    ...
# Thiruvananthapuram  Vattiyoorkavu     133  GEN       Adv.V.K.Prasanth
# Malappuram                Vengara      41  GEN      P.K Kunjhalikutty
# Ernakulam                   Vypen      79  GEN      K.N. Unnikrishnan
# Thrissur            Wadakkanchery      65  GEN  Xavier Chittilappilly
# Malappuram                Wandoor      36   SC          A P Anilkumar
#
#                                                  Party  Total Electors  \
# District
# ...

# %% [markdown]
# # How to change the column name from AC Name to Assemby Constituency

# %%
second_data.rename(columns={'AC Name':'Assemby Constituency' },inplace=True)

# %%
second_data
# Out:
#                    Assemby Constituency  AC No. Type      Winning Candidate  \
# District
# Pathanamthitta                    Adoor     115   SC    Chittayam Gopakumar
# Alappuzha                     Alappuzha     104  GEN       P.P Chitharanjan
# Palakkad                        Alathur      60  GEN           K.D.Prasenan
# Ernakulam                         Aluva      76  GEN           Anwar Sadath
# Alappuzha                   Ambalapuzha     105  GEN                H.Salam
# ...                                 ...     ...  ...                    ...
# Thiruvananthapuram        Vattiyoorkavu     133  GEN       Adv.V.K.Prasanth
# Malappuram                      Vengara      41  GEN      P.K Kunjhalikutty
# Ernakulam                         Vypen      79  GEN      K.N. Unnikrishnan
# Thrissur                  Wadakkanchery      65  GEN  Xavier Chittilappilly
# Malappuram                      Wandoor      36   SC          A P Anilkumar
#
# ...

# %% [markdown]
# # How to remove the index district from second_data

# %%
second_data
# Out:
#                    Assemby Constituency  AC No. Type      Winning Candidate  \
# District
# Pathanamthitta                    Adoor     115   SC    Chittayam Gopakumar
# Alappuzha                     Alappuzha     104  GEN       P.P Chitharanjan
# Palakkad                        Alathur      60  GEN           K.D.Prasenan
# Ernakulam                         Aluva      76  GEN           Anwar Sadath
# Alappuzha                   Ambalapuzha     105  GEN                H.Salam
# ...                                 ...     ...  ...                    ...
# Thiruvananthapuram        Vattiyoorkavu     133  GEN       Adv.V.K.Prasanth
# Malappuram                      Vengara      41  GEN      P.K Kunjhalikutty
# Ernakulam                         Vypen      79  GEN      K.N. Unnikrishnan
# Thrissur                  Wadakkanchery      65  GEN  Xavier Chittilappilly
# Malappuram                      Wandoor      36   SC          A P Anilkumar
#
# ...

# %%
second_data.reset_index(inplace=True)

# %%
second_data
# Out:
#                District Assemby Constituency  AC No. Type  \
# 0        Pathanamthitta                Adoor     115   SC
# 1             Alappuzha            Alappuzha     104  GEN
# 2              Palakkad              Alathur      60  GEN
# 3             Ernakulam                Aluva      76  GEN
# 4             Alappuzha          Ambalapuzha     105  GEN
# ..                  ...                  ...     ...  ...
# 135  Thiruvananthapuram        Vattiyoorkavu     133  GEN
# 136          Malappuram              Vengara      41  GEN
# 137           Ernakulam                Vypen      79  GEN
# 138            Thrissur        Wadakkanchery      65  GEN
# 139          Malappuram              Wandoor      36   SC
#
#          Winning Candidate                               Party  \
# 0      Chittayam Gopakumar            Communist_Party_Of_India
# 1         P.P Chitharanjan  Communist_Party_Of_India_(Marxist)
# 2             K.D.Prasenan  Communist_Party_Of_India_(Marxist)
# ...

# %% [markdown]
# # How to change the data at a row

# %%
first_row_data = second_data.head()

# %%
first_row_data
# Out:
#          District Assemby Constituency  AC No. Type    Winning Candidate  \
# 0  Pathanamthitta                Adoor     115   SC  Chittayam Gopakumar
# 1       Alappuzha            Alappuzha     104  GEN     P.P Chitharanjan
# 2        Palakkad              Alathur      60  GEN         K.D.Prasenan
# 3       Ernakulam                Aluva      76  GEN         Anwar Sadath
# 4       Alappuzha          Ambalapuzha     105  GEN              H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist_Party_Of_India          204205       154817   75.8
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 2  Communist_Party_Of_India_(Marxist)          164415       134583   81.9
# 3            Indian_National_Congress          182360       149489   82.0
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
#
#    Margin  Margin %
# 0    2919       1.9
# 1   11644       7.4
# ...

# %%
first_row_data.loc[1,'District'] = 'Ernakulam'   # Changed from Alappuzha to Ernakulam using method 1

# %%
first_row_data
# Out:
#          District Assemby Constituency  AC No. Type    Winning Candidate  \
# 0  Pathanamthitta                Adoor     115   SC  Chittayam Gopakumar
# 1       Ernakulam            Alappuzha     104  GEN     P.P Chitharanjan
# 2        Palakkad              Alathur      60  GEN         K.D.Prasenan
# 3       Ernakulam                Aluva      76  GEN         Anwar Sadath
# 4       Alappuzha          Ambalapuzha     105  GEN              H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist_Party_Of_India          204205       154817   75.8
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 2  Communist_Party_Of_India_(Marxist)          164415       134583   81.9
# 3            Indian_National_Congress          182360       149489   82.0
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
#
#    Margin  Margin %
# 0    2919       1.9
# 1   11644       7.4
# ...

# %%
first_row_data.at[1,'District'] = 'Alappuzha' # Changed back to alapuzha from ernakulam using method 2

# %%
first_row_data
# Out:
#          District Assemby Constituency  AC No. Type    Winning Candidate  \
# 0  Pathanamthitta                Adoor     115   SC  Chittayam Gopakumar
# 1       Alappuzha            Alappuzha     104  GEN     P.P Chitharanjan
# 2        Palakkad              Alathur      60  GEN         K.D.Prasenan
# 3       Ernakulam                Aluva      76  GEN         Anwar Sadath
# 4       Alappuzha          Ambalapuzha     105  GEN              H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist_Party_Of_India          204205       154817   75.8
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 2  Communist_Party_Of_India_(Marxist)          164415       134583   81.9
# 3            Indian_National_Congress          182360       149489   82.0
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
#
#    Margin  Margin %
# 0    2919       1.9
# 1   11644       7.4
# ...

# %%
first_row_data.groupby('District').get_group('Alappuzha')
# Out:
#     District Assemby Constituency  AC No. Type Winning Candidate  \
# 1  Alappuzha            Alappuzha     104  GEN  P.P Chitharanjan
# 4  Alappuzha          Ambalapuzha     105  GEN           H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
#
#    Margin  Margin %
# 1   11644       7.4
# 4   11125       8.2

# %% [markdown]
# # Adding a new column

# %%
new_cloumn=(first_row_data['Total Electors'])- (first_row_data['Total Votes'])

# %%
new_cloumn
# Out:
# 0    49388
# 1    36830
# 2    29832
# 3    32871
# 4    34861
# dtype: int64

# %%
first_row_data['not voted'] = new_cloumn
# Out:
# C:\Users\Eldhose Varghese\AppData\Local\Temp\ipykernel_18860\3830685453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row_data['not voted'] = new_cloumn

# %%
first_row_data
# Out:
#          District Assemby Constituency  AC No. Type    Winning Candidate  \
# 0  Pathanamthitta                Adoor     115   SC  Chittayam Gopakumar
# 1       Alappuzha            Alappuzha     104  GEN     P.P Chitharanjan
# 2        Palakkad              Alathur      60  GEN         K.D.Prasenan
# 3       Ernakulam                Aluva      76  GEN         Anwar Sadath
# 4       Alappuzha          Ambalapuzha     105  GEN              H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist_Party_Of_India          204205       154817   75.8
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 2  Communist_Party_Of_India_(Marxist)          164415       134583   81.9
# 3            Indian_National_Congress          182360       149489   82.0
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
#
#    Margin  Margin %  Not Voted People  not voted
# ...

# %% [markdown]
# # How to delete not voted column since it appeared 2 times

# %%
first_row_data.drop(columns=['not voted'],inplace=True)
# Out:
# C:\Users\Eldhose Varghese\AppData\Local\Temp\ipykernel_18860\3828454881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row_data.drop(columns=['not voted'],inplace=True)

# %%
first_row_data
# Out:
#          District Assemby Constituency  AC No. Type    Winning Candidate  \
# 0  Pathanamthitta                Adoor     115   SC  Chittayam Gopakumar
# 1       Alappuzha            Alappuzha     104  GEN     P.P Chitharanjan
# 2        Palakkad              Alathur      60  GEN         K.D.Prasenan
# 3       Ernakulam                Aluva      76  GEN         Anwar Sadath
# 4       Alappuzha          Ambalapuzha     105  GEN              H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist_Party_Of_India          204205       154817   75.8
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 2  Communist_Party_Of_India_(Marxist)          164415       134583   81.9
# 3            Indian_National_Congress          182360       149489   82.0
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
#
#    Margin  Margin %  Not Voted People
# 0    2919       1.9             49388
# ...

# %% [markdown]
# # How to delete the first row

# %%
first_row_data.drop(index=0)
# Out:
#     District Assemby Constituency  AC No. Type Winning Candidate  \
# 1  Alappuzha            Alappuzha     104  GEN  P.P Chitharanjan
# 2   Palakkad              Alathur      60  GEN      K.D.Prasenan
# 3  Ernakulam                Aluva      76  GEN      Anwar Sadath
# 4  Alappuzha          Ambalapuzha     105  GEN           H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 2  Communist_Party_Of_India_(Marxist)          164415       134583   81.9
# 3            Indian_National_Congress          182360       149489   82.0
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
#
#    Margin  Margin %  Not Voted People
# 1   11644       7.4             36830
# 2   34118      25.4             29832
# 3   18886      12.6             32871
# 4   11125       8.2             34861

# %% [markdown]
# # How to sort the data on the basis of most majority

# %%
second_data
# Out:
#                District Assemby Constituency  AC No. Type  \
# 0        Pathanamthitta                Adoor     115   SC
# 1             Alappuzha            Alappuzha     104  GEN
# 2              Palakkad              Alathur      60  GEN
# 3             Ernakulam                Aluva      76  GEN
# 4             Alappuzha          Ambalapuzha     105  GEN
# ..                  ...                  ...     ...  ...
# 135  Thiruvananthapuram        Vattiyoorkavu     133  GEN
# 136          Malappuram              Vengara      41  GEN
# 137           Ernakulam                Vypen      79  GEN
# 138            Thrissur        Wadakkanchery      65  GEN
# 139          Malappuram              Wandoor      36   SC
#
#          Winning Candidate                               Party  \
# 0      Chittayam Gopakumar            Communist_Party_Of_India
# 1         P.P Chitharanjan  Communist_Party_Of_India_(Marxist)
# 2             K.D.Prasenan  Communist_Party_Of_India_(Marxist)
# ...

# %%
second_data.sort_values(by=['Margin'],inplace=True)

# %%
second_data
# Out:
#        District Assemby Constituency  AC No. Type           Winning Candidate  \
# 100  Malappuram       Perinthalmanna      38  GEN          Najeeb Kanthapuram
# 69    Kozhikode             Kuttiadi      21  GEN  K P Kunhammed Kutti Master
# 75    Kasaragod           Manjeshwar       1  GEN                A K M Ashraf
# 123    Thrissur             Thrissur      67  GEN              P Balachandran
# 113  Malappuram                Tanur      44  GEN               V.Abdurahiman
# ..          ...                  ...     ...  ...                         ...
# 18     Thrissur           Chelakkara      61   SC             K Radhakrishnan
# 38       Kannur          Kalliasseri       7  GEN                     M Vijin
# 96       Kannur            Payyannur       6  GEN          T  I Madhusoodanan
# 24       Kannur            Dharmadam      12  GEN            Pinarayi Vijayan
# 78       Kannur            Mattannur      15  GEN        K K Shailaja Teacher
#
# ...

# %%
first_row_data
# Out:
#          District Assemby Constituency  AC No. Type    Winning Candidate  \
# 0  Pathanamthitta                Adoor     115   SC  Chittayam Gopakumar
# 1       Alappuzha            Alappuzha     104  GEN     P.P Chitharanjan
# 2        Palakkad              Alathur      60  GEN         K.D.Prasenan
# 3       Ernakulam                Aluva      76  GEN         Anwar Sadath
# 4       Alappuzha          Ambalapuzha     105  GEN              H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist_Party_Of_India          204205       154817   75.8
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 2  Communist_Party_Of_India_(Marxist)          164415       134583   81.9
# 3            Indian_National_Congress          182360       149489   82.0
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
#
#    Margin  Margin %  Not Voted People
# 0    2919       1.9             49388
# ...

# %%
first_row_data.sort_values(by=['Poll%','Margin'],inplace=True)
# Out:
# C:\Users\Eldhose Varghese\AppData\Local\Temp\ipykernel_18860\3749480428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row_data.sort_values(by=['Poll%','Margin'],inplace=True)

# %%
first_row_data
# Out:
#          District Assemby Constituency  AC No. Type    Winning Candidate  \
# 0  Pathanamthitta                Adoor     115   SC  Chittayam Gopakumar
# 4       Alappuzha          Ambalapuzha     105  GEN              H.Salam
# 1       Alappuzha            Alappuzha     104  GEN     P.P Chitharanjan
# 2        Palakkad              Alathur      60  GEN         K.D.Prasenan
# 3       Ernakulam                Aluva      76  GEN         Anwar Sadath
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist_Party_Of_India          204205       154817   75.8
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 2  Communist_Party_Of_India_(Marxist)          164415       134583   81.9
# 3            Indian_National_Congress          182360       149489   82.0
#
#    Margin  Margin %  Not Voted People
# 0    2919       1.9             49388
# ...

# %%
first_row_data.sort_index(inplace=True)
# Out:
# C:\Users\Eldhose Varghese\AppData\Local\Temp\ipykernel_18860\3261148205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row_data.sort_index(inplace=True)

# %%
first_row_data
# Out:
#          District Assemby Constituency  AC No. Type    Winning Candidate  \
# 0  Pathanamthitta                Adoor     115   SC  Chittayam Gopakumar
# 1       Alappuzha            Alappuzha     104  GEN     P.P Chitharanjan
# 2        Palakkad              Alathur      60  GEN         K.D.Prasenan
# 3       Ernakulam                Aluva      76  GEN         Anwar Sadath
# 4       Alappuzha          Ambalapuzha     105  GEN              H.Salam
#
#                                 Party  Total Electors  Total Votes  Poll%  \
# 0            Communist_Party_Of_India          204205       154817   75.8
# 1  Communist_Party_Of_India_(Marxist)          194187       157357   81.0
# 2  Communist_Party_Of_India_(Marxist)          164415       134583   81.9
# 3            Indian_National_Congress          182360       149489   82.0
# 4  Communist_Party_Of_India_(Marxist)          171291       136430   79.6
#
#    Margin  Margin %  Not Voted People
# 0    2919       1.9             49388
# ...

# %% [markdown]
# # How to sort column of District

# %%
first_row_data['District'].sort_values()
# Out:
# 1         Alappuzha
# 4         Alappuzha
# 3         Ernakulam
# 2          Palakkad
# 0    Pathanamthitta
# Name: District, dtype: object

# %%
first_row_data['Margin'].sort_values()
# Out:
# 0     2919
# 4    11125
# 1    11644
# 3    18886
# 2    34118
# Name: Margin, dtype: int64

# %% [markdown]
# # How to get count of null values

# %%
data
# Out:
#        District Assemby Constituency  AC No. Type           Winning Candidate  \
# 100  Malappuram       Perinthalmanna      38  GEN          Najeeb Kanthapuram
# 69    Kozhikode             Kuttiadi      21  GEN  K P Kunhammed Kutti Master
# 75    Kasaragod           Manjeshwar       1  GEN                A K M Ashraf
# 123    Thrissur             Thrissur      67  GEN              P Balachandran
# 113  Malappuram                Tanur      44  GEN               V.Abdurahiman
# ..          ...                  ...     ...  ...                         ...
# 18     Thrissur           Chelakkara      61   SC             K Radhakrishnan
# 38       Kannur          Kalliasseri       7  GEN                     M Vijin
# 96       Kannur            Payyannur       6  GEN          T  I Madhusoodanan
# 24       Kannur            Dharmadam      12  GEN            Pinarayi Vijayan
# 78       Kannur            Mattannur      15  GEN        K K Shailaja Teacher
#
# ...

# %%
data.isnull().sum()
# Out:
# District                0
# Assemby Constituency    0
# AC No.                  0
# Type                    0
# Winning Candidate       0
# Party                   0
# Total Electors          0
# Total Votes             0
# Poll%                   0
# Margin                  0
# Margin %                0
# dtype: int64

# %% [markdown]
# # How to pack data into a csv file ?

# %%
data.to_csv('Worked_out_data.csv')
